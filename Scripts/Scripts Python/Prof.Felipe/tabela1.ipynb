# %%
import pandas as pd

dic_vendas = {"categoria": ["eletrodomesticos", "games", "livros", "casa"],
              "valor": [20000, 50000, 10000, 200000],
              "quantidade": [200, 500, 300, 1500]}

df_vendas = pd.DataFrame(dic_vendas)

df_vendas

df_vendas.sort_values(by="quantidade", ascending=True).plot.bar()
# Out:
# <Axes: >

# %%
# Atividade 1:
# Questão 1:
produtos = {"Nome":["PS5", "Xbox", "PC Gamer", "PS4"],
            "Preco":[3000, 3000, 2500, 1500],
            "Estoque":[20, 50, 25, 50]}
    
produtos_df = pd.DataFrame(produtos)
produtos_df
# Out:
#        Nome  Preco  Estoque
# 0       PS5   3000       20
# 1      Xbox   3000       50
# 2  PC Gamer   2500       25
# 3       PS4   1500       50

# %%
produtos_df.sort_values(by="Preco", ascending=True).plot.bar(x="Nome", y="Preco")
# Out:
# <Axes: xlabel='Nome'>
