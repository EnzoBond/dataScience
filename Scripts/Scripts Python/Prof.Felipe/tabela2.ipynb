# %%
# Atividade 2:
# Questão 2:
import pandas as pd

atletas_dados = {"atletas": ["Michael Phelps", "Neymar", "Usain Bolt", "Truls Moregard"],
           "medalhas": [20, 1, 5, 1],
           "pontuacao": [1000, 100, 500, 100]}

df_atletas = pd.DataFrame(atletas_dados)

# %%
df_atletas.plot.bar(x="atletas", y="medalhas")
# Out:
# <Axes: xlabel='atletas'>

# %%
df_atletas.sort_values(by="pontuacao", ascending=True).plot.bar(x="atletas", y="pontuacao")
# Out:
# <Axes: xlabel='atletas'>
